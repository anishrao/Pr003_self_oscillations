# %%
import glob
import os, time
import itertools
import numpy as np
import seaborn as sns
import pandas as pd
from natsort import natsorted

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from cycler import cycler
from datetime import datetime, timedelta

from scipy.stats import norm
from scipy.optimize import curve_fit #we could import more, but this is what we need
from scipy.stats import linregress
from scipy.signal import find_peaks

from misc_process import normalize_max
from misc_process import get_maxima_LSPR

# %matplotlib inline

# %%
'''
Get paths to corresponsing folders
'''

# get the path to the project's main directory (e.g., Project051)
BASE_DIR_PATH = os.path.dirname(os.path.abspath(os.getcwd()))

# ------------------------- data folder -----------------------

# get the path to the folder containing raw data
DATA_DIR_PATH = os.path.join(BASE_DIR_PATH, 'data', '')

# get the path to the folder containing UV-Vis-NIR raw data
DATA_UV_DIR_PATH_DARK = os.path.join(BASE_DIR_PATH, 'data', 'UV-Vis-NIR','27_06_2023_auss_DNA_40to15_hyst_dark_1mL','')
DATA_UV_DIR_PATH_LIGHT = os.path.join(BASE_DIR_PATH, 'data', 'UV-Vis-NIR','26_06_2023_5to40_hyst_35A','')

DATA_QPOD_DARK = os.path.join(BASE_DIR_PATH, 'data', 'UV-Vis-NIR','27_06_2023_auss_DNA_40to15_hyst_dark_1mL','qpod','')
DATA_QPOD_LIGHT = os.path.join(BASE_DIR_PATH, 'data', 'UV-Vis-NIR','26_06_2023_5to40_hyst_35A','qpod','')


# ------------------------- output folder -----------------------

# # get the path to the folder with generated figures
RESULT_DIR_PATH = os.path.join(BASE_DIR_PATH, 'results', 'figs', '')
RESULT_DIR_PATH_CSV = os.path.join(BASE_DIR_PATH, 'results', 'csv', '')

# %%
#================ import data LIGHT =========================#

# Define the path to the folder containing the CSV files
folder_path_light = DATA_UV_DIR_PATH_LIGHT

# Get a list of all CSV files in the folder
txt_files = natsorted(glob.glob(os.path.join(folder_path_light,'*.txt')))

print(len(txt_files))



#================ plot data LIGHT cycle ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one

# Initialize the maximum value and its corresponding index
max_values = []
max_indexes = []
wv_abs = []

time = 0

for i, txt_file in enumerate(txt_files):
    # Read the CSV file into a Pandas DataFrame
    df = pd.read_csv(txt_file, skiprows=14, delimiter='\t', header=None)
    new_df = df.iloc[324:876, ] # from 350 till 600 nm
    
    # Find the maximum value and its corresponding index
    max_value = new_df[1].max()
    max_values.append(max_value)
    
    # Get the corresponding value from the first column
    max_index = new_df.loc[new_df[1].idxmax(), 0]
    max_indexes.append(max_index)
    
    wv_abs.append((time, max_index, max_value))
    
    time = time + 30 #data plotted in 30 second intervals
    
    # Set the color based on the index of the file
    if i == 0:
        color = 'red'
    elif i == len(txt_files) - 1:
        color = 'blue'
        linestyle = None
    else: 
        color = 'grey'
    
    # Plot the data
    ax.plot(new_df[0],new_df[1], color = color)                           # plot data

#ax.set_xlim([400,1100])                    # set wavelength limit
ax.set_ylim([0,0.9])                       # set absorbance limit
ax.set_xlabel(r'Wavelength (nm)')          # set axis label
ax.set_ylabel(r'Extinction ')              # set axis label
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()  

print('(time, max. wavelength, max. abs)', wv_abs)

df_light = pd.DataFrame(wv_abs, columns=['time(s)','max.wav','abs'])
#df_agg.to_csv(RESULT_DIR_PATH_CSV + 'aggregation.csv', index = False)


df_qpod_light = pd.read_csv(DATA_QPOD_LIGHT + '40to5.txt', header = None, delimiter='\t') # col 0 - time in minutes, and col 1 - temperature
df_qpod_light
# Out:
# 141
# (time, max. wavelength, max. abs) [(0, 526, 0.696), (30, 525, 0.695), (60, 527, 0.693), (90, 526, 0.694), (120, 526, 0.693), (150, 526, 0.693), (180, 527, 0.692), (210, 526, 0.692), (240, 526, 0.692), (270, 526, 0.693), (300, 525, 0.691), (330, 526, 0.692), (360, 525, 0.692), (390, 526, 0.695), (420, 527, 0.695), (450, 526, 0.694), (480, 526, 0.695), (510, 525,
========================#

# Define the path to the folder containing the CSV files
folder_path = DATA_UV_DIR_PATH_DARK

# Get a list of all CSV files in the folder
txt_files = natsorted(glob.glob(os.path.join(folder_path,'*.txt')))

print(len(txt_files))

#================ plot data DARK cycle ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one

# Initialize the maximum value and its corresponding index
max_values = []
max_indexes = []
wv_abs = []

time = 0

for i, txt_file in enumerate(txt_files):
    # Read the CSV file into a Pandas DataFrame
    df = pd.read_csv(txt_file, skiprows=14, delimiter='\t', header=None)
    new_df = df.iloc[324:876, ] # from 350 till 600 nm
    
    # Find the maximum value and its corresponding index
    max_value = new_df[1].max()
    max_values.append(max_value)
    
    # Get the corresponding value from the first column
    max_index = new_df.loc[new_df[1].idxmax(), 0]
    max_indexes.append(max_index)
    
    wv_abs.append((time, max_index, max_value))
    
    time = time + 30 #data plotted in 30 second intervals
    
    # Set the color based on the index of the file
    if i == 0:
        color = 'red'
    elif i == len(txt_files) - 1:
        color = 'blue'
        linestyle = None
    else: 
        color = 'grey'
    
    # Plot the data
    ax.plot(new_df[0],new_df[1], color = color)                           # plot data

#ax.set_xlim([400,1100])                    # set wavelength limit
ax.set_ylim([0,0.9])                       # set absorbance limit
ax.set_xlabel(r'Wavelength (nm)')          # set axis label
ax.set_ylabel(r'Extinction ')              # set axis label
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()  

print('(time, max. wavelength, max. abs)', wv_abs)

df_dark = pd.DataFrame(wv_abs, columns=['time(s)','max.wav','abs'])
#df_agg.to_csv(RESULT_DIR_PATH_CSV + 'aggregation.csv', index = False)

df_qpod_dark = pd.read_csv(DATA_QPOD + '40to15hyst_dark.txt', header = None, delimiter='\t') # col 0 - time in minutes, and col 1 - temperature
df_qpod_dark
# Out:
# 121
# (time, max. wavelength, max. abs) [(0, 526, 0.741), (30, 525, 0.74), (60, 525, 0.74), (90, 526, 0.741), (120, 527, 0.74), (150, 525, 0.738), (180, 524, 0.738), (210, 525, 0.738), (240, 525, 0.738), (270, 527, 0.739), (300, 527, 0.738), (330, 526, 0.737), (360, 526, 0.738), (390, 524, 0.737), (420, 526, 0.738), (450, 525, 0.738), (480, 525, 0.737), (510, 527, 0.739), (540, 525, 0.738), (570, 526, 0.737), (600, 526, 0.737), (630, 526, 0.737), (660, 527, 0.736), (690, 528, 0.729), (720, 529, 0.705), (750, 533, 0.664), (780, 537, 0.62), (810, 545, 0.587), (840, 560, 0.57), (870, 560, 0.556), (900, 561, 0.542), (930, 561, 0.528), (960, 561, 0.513), (990, 575, 0.499), (1020, 575, 0.486), (1050, 575, 0.474), (1080, 579, 0.462), (1110, 579, 0.448), (1140, 575, 0.435), (1170, 578, 0.423), (1200, 579, 0.411), (1230, 578, 0.398), (1260, 579, 0.387), (1290, 579, 0.375), (1320, 579, 0.365), (1350, 579, 0.355), (1380, 579, 0.344), (1410, 561, 0.334), (1440, 561, 0.324), (1470, 561, 0.316), (1500, 561, 0.308), (1530, 561, 0.299), (1560, 561, 0.292), (1590, 561, 0.286), (1620, 561, 0.28), (1650, 561, 0.273), (1680, 561, 0.268), (1710, 561, 0.264), (1740, 561, 0.259), (1770, 561, 0.255), (1800, 561, 0.251), (1830, 560, 0.246), (1860, 561, 0.244), (1890, 561, 0.241), (1920, 561, 0.238), (1950, 560, 0.235), (1980, 561, 0.234), (2010, 561, 0.231), (2040, 561, 0.231), (2070, 561, 0.229), (2100, 561, 0.229), (2130, 561, 0.228), (2160, 561, 0.227), (2190, 561, 0.227), (2220, 561, 0.228), (2250, 561, 0.229), (2280, 561, 0.229), (2310, 561, 0.23), (2340, 561, 0.232), (2370, 561, 0.233), (2400, 561, 0.234), (2430, 561, 0.236), (2460, 561, 0.238), (2490, 561, 0.241), (2520, 561, 0.242), (2550, 561, 0.245), (2580, 561, 0.247), (2610, 561, 0.25), (2640, 561, 0.252), (2670, 561, 0.255), (2700, 561, 0.256), (2730, 561, 0.258), (2760, 561, 0.261), (2790, 561, 0.263), (2820, 560, 0.266), (2850, 537, 0.274), (2880, 536, 0.304), (2910, 531, 0.354), (2940, 530, 0.433), (2970, 527, 0.528), (3000, 526, 0.607), (3030, 526, 0.662), (3060, 525, 0.693), (3090, 526, 0.712), (3120, 525, 0.72), (3150, 526, 0.723), (3180, 525, 0.723), (3210, 525, 0.722), (3240, 526, 0.722), (3270, 526, 0.721), (3300, 526, 0.719), (3330, 527, 0.719), (3360, 526, 0.719), (3390, 527, 0.718), (3420, 526, 0.718), (3450, 525, 0.719), (3480, 526, 0.718), (3510, 527, 0.719), (3540, 526, 0.718), (3570, 526, 0.719), (3600, 526, 0.718)]
#           0      1
# 0     0.000  40.00
# 1     0.500  40.00
# 2     1.000  40.00
# 3     1.500  40.00
# 4     2.000  39.88
# ..      ...    ...
# 105  52.501  40.09
# 106  53.001  39.98
# 107  53.501  39.99
# 108  54.001  40.00
# 109  54.501  40.00
#
# [110 rows x 2 columns]

# %%
df_dark[:110]
# Out:
#      time(s)  max.wav    abs
# 0          0      526  0.741
# 1         30      525  0.740
# 2         60      525  0.740
# 3         90      526  0.741
# 4        120      527  0.740
# ..       ...      ...    ...
# 105     3150      526  0.723
# 106     3180      525  0.723
# 107     3210      525  0.722
# 108     3240      526  0.722
# 109     3270      526  0.721
#
# [110 rows x 3 columns]

# %%
#================ plot data hysteresis - lambda max ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod_dark[1], df_dark['max.wav'][:110], label = 'Dark')                           # plot data

#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Time (s)')          # set axis label
ax.set_ylabel(r'$\lambda_{max.}$')              # set axis label
ax.legend(frameon=False)
ax.set_xlabel('Temp ($^{\circ}$C)')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

# %%
#================ plot data hysteresis - lambda max ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod_dark[1], df_dark['abs'][:110], label = 'Dark')                           # plot data

#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Temp ($^{\circ}$C)')          # set axis label
ax.set_ylabel(r'Abs. at $\lambda_{max.}$')              # set axis label
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()  

#plt.savefig(RESULT_DIR_PATH + '3.5A_40to5C_hysteresis.jpeg')

# %%
fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod_light[1], df_light['abs'], label = 'Light-3.5A', color = 'lightcoral')                           # plot data

ax.plot(df_qpod_dark[1], df_dark['abs'][:110], label = 'Dark', color = 'firebrick')                           # plot data

#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Temp ($^{\circ}$C)')          # set axis label
ax.set_ylabel(r'Abs. at $\lambda_{max.}$')              # set axis label
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()  

#plt.savefig(RESULT_DIR_PATH + '3.5A_40to5C_hysteresis_light_dark.jpeg')

# %%
fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod_light[1], np.gradient(df_light['abs']), label = 'Light-3.5A', color = 'lightcoral')                           # plot data

ax.plot(df_qpod_dark[1], np.gradient(df_dark['abs'][:110]), label = 'Dark', color = 'firebrick')                           # plot data

peaks, _ = find_peaks(np.gradient(df_light['abs']), height=0.001)
print(peaks)

#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Temp ($^{\circ}$C)')          # set axis label
ax.set_ylabel(r'Abs. at $\lambda_{max.}$´')              # set axis label
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.axvline(12, color = 'royalblue')
ax.axvline(19, color = 'firebrick')

ax.axvline(29, color = 'royalblue')
ax.axvline(37, color = 'firebrick')

plt.tight_layout()  

#plt.savefig(RESULT_DIR_PATH + '3.5A_40to5C_hysteresis_light_dark.jpeg')
# Out:
# [12 19 22 28 31 35 39 47 52 55 96]

# %%
fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod_light[1], np.gradient(np.gradient(df_light['abs'])), label = 'Light-3.5A', color = 'lightcoral')                           # plot data

ax.plot(df_qpod_dark[1], np.gradient(np.gradient(df_dark['abs'][:110])), label = 'Dark', color = 'firebrick')                           # plot data

#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Temp ($^{\circ}$C)')          # set axis label
ax.set_ylabel(r'Abs. at $\lambda_{max.}$´´')              # set axis label
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()  

#plt.savefig(RESULT_DIR_PATH + '3.5A_40to5C_hysteresis_light_dark.jpeg')

# %%
#================ plot data hysteresis - lambda max ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod[1], np.gradient(df_agg['abs']), label = '3.5A')                           # plot data
ax.axvline(12, color = 'royalblue')
ax.axvline(19, color = 'firebrick')

peaks, _ = find_peaks(np.gradient(df_agg['abs']), height=0)
print(peaks)
#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Temp ($^{\circ}$C)')          # set axis label
ax.set_ylabel(r'Abs. at $\lambda_{max.}$`')              # set axis label
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.tight_layout()
# Out:
# [  3   8  12  19  22  28  31  35  39  42  47  52  55  58  96 109 113 118
#  122 125 128 132 136]

# %%
#================ plot data hysteresis - lambda max ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_qpod[1], np.gradient(np.gradient(df_agg['abs'])), label = '3.5A')                           # plot data
ax.axvline(11.5, color = 'royalblue')
ax.axvline(19.5, color = 'firebrick')

#ax.set_xlim([300,2820])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Temp ($^{\circ}$C)')          # set axis label
ax.set_ylabel(r'Abs. at $\lambda_{max.}$``')              # set axis label
ax.legend(frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.tight_layout()

# %%
condition = df_agg['time(s)'] % 30  == 0
# Use boolean indexing to select rows based on the condition
df_selected = df_agg[condition]
# Reset the index if needed
df_selected.reset_index(drop=True, inplace=True)
df_selected

# %%
combined_df = pd.concat([df_agg, df_qpod])
# Reset the index if needed
combined_df.reset_index(drop=True, inplace=True)
combined_df
# Out:
#      time(s)  max.wav    abs  time_sec   temp
# 0        0.0    525.0  0.714       NaN    NaN
# 1       10.0    526.0  0.714       NaN    NaN
# 2       20.0    527.0  0.715       NaN    NaN
# 3       30.0    526.0  0.715       NaN    NaN
# 4       40.0    525.0  0.714       NaN    NaN
# ..       ...      ...    ...       ...    ...
# 579      NaN      NaN    NaN   4470.12  38.87
# 580      NaN      NaN    NaN   4500.06  39.37
# 581      NaN      NaN    NaN   4530.12  39.87
# 582      NaN      NaN    NaN   4560.12  40.03
# 583      NaN      NaN    NaN   4590.12  39.94
#
# [584 rows x 5 columns]

# %%
#================ plot data hysteresis - lambda max ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_agg['time(s)'], df_agg['max.wav'], label = 'cooling')                           # plot data

ax.set_xlim([2820,3350])                   
ax.set_ylim([520,600])                       
ax.set_xlabel(r'Time (s)')          # set axis label
ax.set_ylabel(r'$\lambda_{max.}$')              # set axis label
ax.legend(frameon=False)
ax.axvline(30)
ax.axvline(20)

#================ plot data hysteresis - lambda max ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one


ax.plot(df_agg['time(s)'], df_agg['abs'], label = 'cooling')                           # plot data

ax.set_xlim([2820,3350])                   
#ax.set_ylim([520,600])                       
ax.set_xlabel(r'Time (s)')          # set axis label
ax.set_ylabel(r'$\lambda_{max.}$')              # set axis label
ax.legend(frameon=False)
ax.axvline(30)
ax.axvline(20)

plt.tight_layout()
