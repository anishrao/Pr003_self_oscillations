# %%
#%matplotlib widget
# %matplotlib inline

import glob
import os, time
import itertools
import numpy as np
import seaborn as sns
import pandas as pd
from natsort import natsorted
import pygwalker as pyg


import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from cycler import cycler
from datetime import datetime, timedelta

from scipy.stats import norm
from scipy.optimize import curve_fit #we could import more, but this is what we need
from scipy.stats import linregress

#from misc_process import *
#from misc_process import get_maxima_LSPR

# %%
'''
Get paths to corresponsing folders
'''

# get the path to the project's main directory (e.g., Project051)
BASE_DIR_PATH = os.path.dirname(os.path.abspath(os.getcwd()))

# ------------------------- data folder -----------------------

# get the path to the folder containing raw data
DATA_DIR_PATH = os.path.join(BASE_DIR_PATH, 'data','')

# get the path to the folder containing UV-Vis-NIR raw data
DATA_UV_DIR_PATH = os.path.join(BASE_DIR_PATH, 'data', 'UV-Vis-NIR','2023-08-29-aunr-dna2-2dna-stability-assembly','')

# ------------------------- output folder -----------------------

# # get the path to the folder with generated figures
RESULT_DIR_PATH = os.path.join(BASE_DIR_PATH, 'results', 'figs', '')
RESULT_DIR_PATH_SI = os.path.join(BASE_DIR_PATH, 'results', 'figs', 'si_figs', 'png', '')

# %%
'''
Import example data from UV-Vis-NIR folder
'''

#================ import data =========================#

# import file using read_csv function in pandas
df = pd.read_csv(DATA_UV_DIR_PATH+'2023-08-29-AuNR-DNA2.csv')
columns = df.columns
df_nacl = pd.read_csv(DATA_UV_DIR_PATH + '2023-08-29-AuNR-DNA2.csv', skiprows=1)

df_abs = df_nacl.iloc[:, 1::2]
df_abs
# Out:
#           Abs     Abs.1     Abs.2     Abs.3     Abs.4     Abs.5     Abs.6  \
# 0    0.007481  0.006318  0.001896  0.000702  0.003158  0.005460  0.002282
# 1    0.003763  0.001673  0.000820  0.000666  0.002992  0.002572  0.001659
# 2    0.007736  0.005288  0.002421  0.003497  0.006442  0.006781  0.007333
# 3    0.005348  0.003309  0.003291  0.002384  0.000234  0.002765  0.000710
# 4    0.005208  0.004580  0.003857  0.004143  0.002288  0.003950  0.000177
# ..        ...       ...       ...       ...       ...       ...       ...
# 796  0.203344  0.168104  0.154045  0.132908  0.080057  0.141696  0.128365
# 797  0.204218  0.168529  0.154494  0.133538  0.079682  0.142566  0.129191
# 798  0.205082  0.169424  0.155174  0.134350  0.079682  0.142639  0.129570
# 799  0.205946  0.170089  0.156157  0.134935  0.079998  0.143755  0.130158
# 800  0.207603  0.171339  0.156967  0.135780  0.080409  0.144564  0.131182
#
#         Abs.7     Abs.8     Abs.9  ...    Abs.16    Abs.17    Abs.18  \
# ...

# %% [markdown]
# # Effect of sodium chloride on AuNRs

# %%
'''
Make a simple figure containing normalized data 
'''
#================ plot data ===========================#

fig = plt.figure(figsize=(2,2), dpi=300) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one

# Select first 5 columns
df_nacl_init = df_nacl.iloc[:,1:11:2]

# Set color 
cm_subsection = np.linspace(0, 1, len(df_nacl_init.columns))
cyc = cycler(color=[cm.coolwarm_r(x) for x in cm_subsection])
line_widths = [2, 0, 0, 0, 0]
ax.set_prop_cycle(cyc)

# Column names
col_nacl_init = ['AuNRs', '300mM NaCl', '400mM NaCl', '600mM NaCl', '1000mM NaCl']

# Plot data
for i, col in enumerate(df_nacl_init.columns):
    ax.plot(df_nacl['Wavelength (nm)'], df_nacl_init[col], linewidth=line_widths[i])
ax.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
#ax.axvline(x=688, color = 'grey', linewidth = 0.75, linestyle = '--')
ax.set_xlabel(r'Wavelength (nm)')          # set axis label
ax.set_ylabel(r'Extinction')              # set axis label

# #================ plot stylisation ====================#

ax.spines['right'].set_visible(False)      # remove spines
ax.spines['top'].set_visible(False)

plt.tight_layout()  
fig.savefig(RESULT_DIR_PATH_SI + 'aunr -dna2.png', bbox_inches='tight', transparent = True)

# %% [markdown]
# # Effect of time

# %%
'''
Make a simple figure containing normalized data 
'''
#================ plot data ===========================#
fig = plt.figure(figsize=(6,4), dpi=600)
gs = fig.add_gridspec(2, 2) #nrows, #ncolumns
ax1 = fig.add_subplot(gs[0, 0]) # upper left subplot
ax2 = fig.add_subplot(gs[0, 1]) # upper rigth subplot
ax3 = fig.add_subplot(gs[1, 0]) # lower left subplot
ax4 = fig.add_subplot(gs[1, 1]) # lower right subplot

axes = [ax1, ax2, ax3, ax4] # list of all axes in plot

ax1.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.1'], color = 'firebrick')
ax1.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.9'], color = 'royalblue')
ax1.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
ax1.axvline(x=687, color = 'grey', linewidth = 0.75, linestyle = '--')
ax1.set_xlabel(r'Wavelength (nm)')          # set axis label
ax1.set_ylabel(r'Extinction')              # set axis label
#ax.legend(['Au@BSPP@70$^{o}$C','Au@BSPP@5$^{o}$C'], fontsize='small',frameon=False)

ax2.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.2'], color = 'firebrick')
ax2.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.10'], color = 'royalblue')
ax2.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
ax2.axvline(x=687, color = 'grey', linewidth = 0.75, linestyle = '--')
ax2.set_xlabel(r'Wavelength (nm)')          # set axis label
ax2.set_ylabel(r'Extinction')              # set axis label
#ax.legend(['Au@BSPP@70$^{o}$C','Au@BSPP@5$^{o}$C'], fontsize='small',frameon=False)

ax3.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.3'], color = 'firebrick')
ax3.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.11'], color = 'royalblue')
ax3.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
ax3.axvline(x=687, color = 'grey', linewidth = 0.75, linestyle = '--')
ax3.set_xlabel(r'Wavelength (nm)')          # set axis label
ax3.set_ylabel(r'Extinction')              # set axis label
#ax.legend(['Au@BSPP@70$^{o}$C','Au@BSPP@5$^{o}$C'], fontsize='small',frameon=False)

ax4.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.4'], color = 'firebrick')
ax4.plot(df_nacl['Wavelength (nm)'], df_nacl['Abs.12'], color = 'royalblue')
ax4.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
ax4.axvline(x=687, color = 'grey', linewidth = 0.75, linestyle = '--')
ax4.set_xlabel(r'Wavelength (nm)')          # set axis label
ax4.set_ylabel(r'Extinction')              # set axis label
#ax.legend(['Au@BSPP@70$^{o}$C','Au@BSPP@5$^{o}$C'], fontsize='small',frameon=False)

# #================ plot stylisation ====================#

ax1.spines['right'].set_visible(False)      # remove spines
ax1.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)      # remove spines
ax2.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)      # remove spines
ax3.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)      # remove spines
ax4.spines['top'].set_visible(False)

plt.tight_layout()  
# fig.savefig(RESULT_DIR_PATH+'example_1subplot.pdf')

print(columns)
# Out:
# Index(['10uL-AuNRDNA2-300uLH2O', 'Unnamed: 1', '300mM-NaCl-0925', 'Unnamed: 3',
#        '400mM-NaCl-0929', 'Unnamed: 5', '600mM-NaCl-0933', 'Unnamed: 7',
#        '1000mM-NaCl-0937', 'Unnamed: 9', '300mM-NaCl-1140', 'Unnamed: 11',
#        '400mM-NaCl-1140', 'Unnamed: 13', '600mM-NaCl-1141', 'Unnamed: 15',
#        '1000mM-NaCl-1142', 'Unnamed: 17', '300mM-NaCl-1401', 'Unnamed: 19',
#        '400mM-NaCl-1402', 'Unnamed: 21', '600mM-NaCl-1403', 'Unnamed: 23',
#        '1000mM-NaCl-1403', 'Unnamed: 25', '300mM-NaCl-1406-36-5uLBP2',
#        'Unnamed: 27', '400mM-NaCl-1408-38-7uLBP2', 'Unnamed: 29',
#        '600mM-NaCl-1410-44-3uLBP2', 'Unnamed: 31', '300mM-NaCl-1553-36-5uLBP2',
#        'Unnamed: 33', '400mM-NaCl-1554-38-7uLBP2', 'Unnamed: 35',
#        '600mM-NaCl-1555-44-3uLBP2', 'Unnamed: 37',
#        '400mM-NaCl-0-01SDS-1611-init', 'Unnamed: 39',
#        '400mM-NaCl-0-01SDS-1611-38-7uLBP2-1614', 'Unnamed: 41',
# ...

# %%
'''
Make a simple figure containing normalized data 
'''
#================ plot data ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one

# Set color 
cm_subsection = np.linspace(0, 1, len(df_abs.columns))
cyc = cycler(color=[cm.coolwarm_r(x) for x in cm_subsection])
ax.set_prop_cycle(cyc)

ax.plot(df_nacl['Wavelength (nm)'], df_abs)
ax.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
ax.axvline(x=687, color = 'grey', linewidth = 0.75, linestyle = '--')
ax.set_xlabel(r'Wavelength (nm)')          # set axis label
ax.set_ylabel(r'Extinction')              # set axis label
#ax.legend(['Au@BSPP@70$^{o}$C','Au@BSPP@5$^{o}$C'], fontsize='small',frameon=False)

# #================ plot stylisation ====================#

ax.spines['right'].set_visible(False)      # remove spines
ax.spines['top'].set_visible(False)

plt.tight_layout()  
# fig.savefig(RESULT_DIR_PATH+'example_1subplot.pdf')

print(columns)

# %%
dfh = pd.read_csv(DATA_UV_DIR_PATH + '2023-08-30-aunr-dna2-50C.csv')
col_heat = dfh.columns

df_heat = pd.read_csv(DATA_UV_DIR_PATH + '2023-08-30-aunr-dna2-50C.csv', skiprows = 1)

df_heat_abs = df_heat.iloc[:, 1::2]
df_heat_abs
# Out:
#           Abs     Abs.1     Abs.2     Abs.3     Abs.4
# 0    0.004317  0.006357  0.005012  0.002042  0.004724
# 1    0.007015 -0.001360 -0.000447  0.001685  0.006237
# 2    0.007023  0.001419  0.001109 -0.000456  0.004079
# 3    0.005510  0.004392  0.002416  0.001476  0.005917
# 4    0.005560  0.003078 -0.000242  0.000189  0.005274
# ..        ...       ...       ...       ...       ...
# 796  0.102433  0.081455  0.053514  0.014417  0.138557
# 797  0.108378  0.086208  0.058079  0.014374  0.143128
# 798  0.115069  0.092021  0.063782  0.014202  0.148290
# 799  0.123927  0.099301  0.070882  0.013936  0.155712
# 800  0.134600  0.108736  0.080273  0.013869  0.164520
#
# [801 rows x 5 columns]

# %%
'''
Make a simple figure containing normalized data 
'''
#================ plot data ===========================#

fig = plt.figure(figsize=(4,2), dpi=600) # generate a figure
ax = plt.subplot(1,1,1) #(nrow, ncolumn, index) - make a subplot, there is only one

# Set color 
cm_subsection = np.linspace(0, 1, len(df_heat_abs.columns))
cyc = cycler(color=[cm.coolwarm_r(x) for x in cm_subsection])
ax.set_prop_cycle(cyc)

ax.plot(df_heat['Wavelength (nm)'], df_heat_abs)
ax.set_xlim([400,1100])                    # set wavelength limit
#ax.set_ylim([0,2.7])                       # set absorbance limit
ax.axvline(x=687, color = 'grey', linewidth = 0.75, linestyle = '--')
ax.set_xlabel(r'Wavelength (nm)')          # set axis label
ax.set_ylabel(r'Extinction')              # set axis label
#ax.legend(['Au@BSPP@70$^{o}$C','Au@BSPP@5$^{o}$C'], fontsize='small',frameon=False)

# #================ plot stylisation ====================#

ax.spines['right'].set_visible(False)      # remove spines
ax.spines['top'].set_visible(False)

plt.tight_layout()  
# fig.savefig(RESULT_DIR_PATH+'example_1subplot.pdf')

print(col_heat)
# Out:
# Index(['300mMNaCl-d2-10mins-50C', 'Unnamed: 1', '400mMNaCl-d2-10mins-50C',
#        'Unnamed: 3', '600mMNaCl-d2-10mins-50C', 'Unnamed: 5',
#        '1000mMNaCl-d2-10mins-50C-correct', 'Unnamed: 7',
#        '400mMNaCl-d2-10mins-50C-sds', 'Unnamed: 9'],
#       dtype='object')
